# %% [markdown]
# Certainly! Here are some notes on Seaborn, a popular Python visualization library built on top of Matplotlib:
# #### Why seaborn ?
# - Provides a layer of abstraction hence simpler to use(We see we have to write multiple codes in matplotlib to make a good manager)
# - Better Aesthetics(even in Default seaborn's graph looks more appealing**)
# - More Graphs included
#
# #### Types of Functions:
# - Figure level Functions
# - Axis level Functions
#
# 1. **Introduction**:
#    - Seaborn is a statistical data visualization library in Python.
#    - It provides a high-level interface for drawing attractive and informative statistical graphics.
#    - It is built on top of Matplotlib and integrates closely with Pandas data structures.
#
# 2. **Key Features**:
#    - **High-Level Interface**: Seaborn provides a simple and intuitive API for creating complex statistical visualizations.
#    - **Statistical Estimation**: Seaborn offers functions to summarize and visualize distributions and relationships in datasets.
#    - **Integration with Pandas**: Seaborn seamlessly works with Pandas DataFrames, making it easy to visualize data stored in tabular formats.
#    - **Attractive Default Styles**: Seaborn comes with visually pleasing default styles and color palettes that enhance the aesthetics of plots.
#    - **Flexible Plotting Functions**: Seaborn offers a wide range of plotting functions for various types of data visualization, including univariate and bivariate plots, categorical plots, and time series plots.
#    - **Advanced Customization**: Seaborn allows for extensive customization of plots, including control over colors, styles, labels, and annotations.
#
# 3. **Commonly Used Plotting Functions**:
#    - **Distribution Plots**: `sns.histplot()`, `sns.kdeplot()`, `sns.distplot()` for visualizing univariate distributions.
#    - **Categorical Plots**: `sns.barplot()`, `sns.countplot()`, `sns.boxplot()` for visualizing relationships between categorical variables.
#    - **Scatter Plots**: `sns.scatterplot()`, `sns.jointplot()`, `sns.pairplot()` for visualizing relationships between numerical variables.
#    - **Regression Plots**: `sns.regplot()`, `sns.lmplot()`, `sns.residplot()` for visualizing linear regression models.
#    - **Matrix Plots**: `sns.heatmap()`, `sns.clustermap()` for visualizing matrices of data.
#
# 4. **Integration with Matplotlib**:
#    - Seaborn is built on top of Matplotlib and can be used alongside Matplotlib functions for additional customization.
#    - Matplotlib functions can be invoked directly for fine-grained control over plot elements.
#
# 5. **Installation and Compatibility**:
#    - Seaborn can be installed via pip (`pip install seaborn`) or conda (`conda install seaborn`).
#    - It is compatible with Python 3.x and integrates well with other scientific computing libraries such as NumPy, Pandas, and SciPy.
#
# 6. **Documentation and Resources**:
#    - Seaborn provides comprehensive documentation with examples and tutorials to help users get started.
#    - The Seaborn community is active, with forums and online resources available for support and collaboration.
#
# Overall, Seaborn is a powerful and versatile tool for creating informative and visually appealing statistical visualizations in Python, making it an essential library for data analysis and exploration tasks.

# %% [markdown]
# # Seaborn Graphs
#
# ### Relational plots:
# To see the relation between 2 or more variables,  Bivariate Analysis
# - Scatterplot
# - Lineplot
#
# ### Distribution plot:
#
# - Histogram
# - kdeplot
# - Rugplot
#
# ### Categorical
# - Barplot
# - Countplot
# - Boxplot
# - Voilin
#
# ### Matrix
# - Heatmap
#
# ### Regression Plots
# - Regplot

# %% [markdown]
# https://seaborn.pydata.org/api.html

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %% [markdown]
# we will use 'tips' dataset for now

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Features:
#
# - total_bill: Total bill amount (including tax and tip).
# - tip: Tip amount given by the customer.
# - sex: Gender of the customer (male or female).
# - smoker: Whether the customer is a smoker (yes or no).
# - day: Day of the week (Thursday, Friday, Saturday, Sunday).
# - time: Time of the day (Lunch or Dinner).
# - size: Number of people in the dining party.

# %%
# Relational plot 

sns.scatterplot(x=df.total_bill,y=df.tip)

# It is a axis level function

# Let say if you are in matplotlib then u have to tell the pc that what is x label and y label
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Replot -> Figure level function -> Square shaped 
# seaborn recommends regplot but we can use scatterplot instead for ease now
# what seaborn suggests is we should use figure level functions more 

sns.relplot(x=df.total_bill,y=df.tip, kind='scatter')
plt.show()

# %%
#Hue parameter 
# particular features

sns.scatterplot(x=df.total_bill,y=df.tip, hue=df.sex)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# style Parameter 
# we can add one more layer of information, lets say i want see yaha kitne log dinner ke time aaye or kitne lunch ke time aaye

# %%
#Now we have 4 layers of information
sns.scatterplot(x=df.total_bill,y=df.tip, hue=df.sex, style=df.time)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# size parameter 
# Lets say i want to check koi customer kitne logo ke saath aya

# %%
sns.scatterplot(x=df.total_bill,y=df.tip, hue=df.sex, style=df.time, size=df.size)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Line plot 
# Line plot is basically a scatterplot 
# this is where we use continuity in graph 
# Let say we have scatterplot points, if we join all these points we will get a line plot 
# it is more used for time-series data

# %% [markdown]
# Time series data refers to a sequence of data points collected or recorded at successive and equally spaced intervals of time. In other words, it is a series of observations or measurements obtained over a specific period, where each data point is associated with a particular timestamp or time period.
#
# Time series data is just a fancy way of saying data that changes over time. Imagine you're keeping track of something, like the temperature outside, every hour. Each hour, you write down the temperature. That's a time series! It's like a timeline of data points where each point has a time stamp.

# %%
import plotly.express as px

# %%
df= px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# The Gapminder dataset typically includes the following columns:
#
# - country: The name of the country.
# - year: The year for which the data was recorded.
# - pop: Population of the country.
# - continent: The continent to which the country belongs.
# - lifeExp: Life expectancy at birth for the country.
# - gdpPercap: GDP per capita (income per person) for the country.
# - iso_alpha: ISO 3166-1 alpha-3 country code.
#
# These columns provide information about various socio-economic indicators for different countries over time, allowing for analysis of trends in global development, comparisons between countries, and exploration of relationships between different variables.
#
# Pieces of information:
# - Country name
# - year
# - Life exp
# - gdppercap

# %%
dat_ind = df[df.country=='India']

# %%
dat_ind
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# axes level function

sns.lineplot(data=dat_ind, x='year', y='lifeExp')
plt.show()

# %%
#how can we make this using relplot 

sns.relplot(data=dat_ind, x='year', y='lifeExp', kind='line')

# %%
# we will use parameters now 
# for example we have 3 countries, we want to check lifeExp of 3 countries 

tempdata = df[df['country'].isin(["India","Pakistan","China"])]

# %%
tempdata
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.lineplot(data=tempdata, x='year', y='lifeExp', hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(kind='line',data=tempdata, x='year', y='lifeExp', hue='country')

# %% [markdown]
# - difference between rel and line, since rel is figure level it pushes out legend out of the graph since it is figure level function

# %%
tempdata = df[df['country'].isin(["India","Germany","Zimbabwe"])]

# %%
tempdata
# Out:
#        country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564    Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565    Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566    Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567    Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568    Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569    Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570    Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571    Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572    Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573    Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574    Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
sns.relplot(kind='line',data=tempdata, x='year', y='lifeExp', hue='country', style='continent')

# %%
# facet plot 

df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data = df, x='total_bill', y='tip', kind='scatter', hue='sex')

# %% [markdown]
# - Zyada acche se smjh ni aara
# - likewise what if we could make different graph in same figure for both male and female

# %%
sns.relplot(data = df, x='total_bill', y='tip', kind='scatter', col='sex')
plt.show()

# %%
sns.relplot(data = df, x='total_bill', y='tip', kind='scatter', row='sex')
plt.show()

# %% [markdown]
# also,

# %%
sns.relplot(data = df, x='total_bill', y='tip', kind='scatter', col='sex', row='smoker')
plt.show()

# %%
sns.relplot(data = df, x='total_bill', y='tip', kind='scatter', col='sex', row='day')
plt.show()

# %%
# You have to remember that facetplot only with figure level functions like, relplot /

# %%
# col wrap 

#again using gapminder 

df= px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.relplot(data=df, x='lifeExp',y='gdpPercap', kind='scatter', col='year')

# %% [markdown]
# - not readable because it is too small
# - so we will use col wrap

# %%
sns.relplot(data=df, x='lifeExp',y='gdpPercap', kind='scatter', col='year', col_wrap=3)

# %% [markdown]
# # Distribution plots
#
# It tell us about the distribution of the data. like data kaise faila hua hai
# for example like, we have data of salaries for example some person is having 2 lakh salary, someone is having 5 lakh and someone is having 1 crore
# likewise, we can plot this on number line and see the spread
# ho skta hai ki line ka data pe data biased ho
#
# 1. used for univariate analysis
# 2. used to findout the distribution
# 3. range of observation
# 4. central tendency
# 5. is the data bimodel ?(Multiple peaks)
# 6. Are their any outliers
#
# ## Plots under distribution plots
#
# - histplot
# - kdeplot
# - rugplot

# %% [markdown]
# # Histplot
# # lets say, bin count of the data for example we have salaries model it will make ranges, and plot the count in that specific cluster

# %% [markdown]
# ### Figure level = displot
# ### Axis level = histplot -> kdeplot -> rugplot

# %%
# ploting univariate histogram 

# it is used for ranged data

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# axis level
sns.histplot(data=df, x="total_bill")
plt.show()

# %%
#figure level
sns.displot(kind='hist',x=df.total_bill)

# %%
#want to increase or decrease number of bins
#bins parameter
sns.displot(kind='hist',x=df.total_bill,bins=20)
# if we increase bin size we will get thinner bin size and vice versa

# %%
# You could also make histogram on categorical columns 
# on categorical columns it works like a countplot 
# figure level function**
sns.displot(kind='hist',data=df,x='day')

# %%
# parameter hue 
# with tip 
sns.displot(kind='hist',data=df,x='tip',hue='sex')

# %%
#parameter element= step it will make the graph look more clean 

sns.displot(kind='hist',data=df,x='tip',hue='sex',element='step')

# %%
sns.displot(x=df.tip,kde=False)

# %% [markdown]
# # bins parameter
#
# - likewise we can we can increase or decrease the number of bins

# %%
sns.displot(x=df.tip,kde=False,bins=5)
#thick bars because we are using reduced the number to 5 or vice versa

# %%
# it is possible to visualise the distribution of a categorical variable using the logic of histogram 
# Discrete bins are automatically set for categorical variables

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# i want to see how many customers came on specific day

# %%
sns.histplot(data=df,x='day')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=df,x='day',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
# we will use an interesting dataset 

df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - PassengerId: A unique identifier for each passenger.
# - Survived: Indicates whether the passenger survived (1) or not (0).
# - Pclass: The ticket class of the passenger (1st, 2nd, or 3rd).
# - Name: The name of the passenger.
# - Sex: The gender of the passenger.
# - Age: The age of the passenger (in years).
# - SibSp: The number of siblings or spouses the passenger had aboard the Titanic.
# - Parch: The number of parents or children the passenger had aboard the Titanic.
# - Ticket: The ticket number.
# - Fare: The fare the passenger paid for the ticket.
# - Cabin: The cabin number.
# - Embarked: The port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
# it basically works on ranges 
sns.histplot(data=df,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(kind='hist',data=df,x='age',col='sex')

# %% [markdown]
# ### KDE plot, Kernal density Plot, kernal density estimation
# ### rather than using discrete bins, a kde plot smooths the observation with the gaussian kernel, producing the conitinous desnity estimate

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# y axis pe you will get density of the plot 

sns.kdeplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# - it tells us about the probablity likewise, on 18 point on x axis, ki uski probablity zyada hai 50% ke kreeb
# - it is used more than the hist plot because it gives more info then hist, likewise it tells hidden values as well
# - it is continous, yaha kuch v miss ni hota
# - but it depends ki use krna hai ki ni

# %%
# parameters hue 

sns.displot(kind='kde',x='total_bill',hue='sex',data=df)

# %%
# additional setting, fill= true

sns.displot(kind='kde',x='total_bill',hue='sex',data=df, fill=True)

# %% [markdown]
# ### Rugplot
#
# #### not much useful but you use it for additional information
# #### plot marginal distribution by drawing ticks along the x and y axis
#
# #### This function is intended to compliment other plots by showing the location of individual observation in an intrusive way
# compliment krte hai or alag se dikhai deta hai

# %%
sns.kdeplot(x='total_bill',data=df)
sns.rugplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# what basically it is doing, it is ploting a point on number line everytime it sees an entry
# like apne paas ek range hai salaries ka, usmein jitni jitni salaries hongi wo number line pe ek point chhodengi
#
# - hist jaise ek ke upar ek plot krta hai ye side by side krta hai

# %%
# you can also make bi variate histogram 

# a bivariate histogram bins the data within rectangles that tile the plot 

sns.histplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# - ye indono ka representation bta rha hai and we can see, jo jitna dark hai uske andr utni hi zyada values hai
# - it tells us about the frequency

# %%
# we can also make bi variate kde plot 

sns.kdeplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# - jis are mein lines zyada close aari hai waha zyada frequency hai and wo jagah dense hai

# %% [markdown]
# ### Done second portion of this part

# %% [markdown]
# # Matrix plot
#
# - Heat map
# - clustermap

# %%
# heat map
# plot rectangular data as color-encoded matrix 

df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#################################################################################

# what i want to do make a grid with countries on one axis and and plot life expentancy on another axis 
# wide vs long data set 
# to convert long data set to wide data set 
# abhi ke liye nhi krte 

df= sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# with correlations 
# correlations is basically how two variables are related
# for example, price of the product and demand of the product 
# positive and negative correlation, one variable increase and other will also increase 

sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
# we will use mpg data set to under corr better

df= sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# - miles per gallon
# - number of cylinders in engine
# - Engine displacement in cubic inches
# - horspower
# - weight
# - acceleration

# %%
df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# changing plot rectangular data as a color encoded matrix 
# to convert long data set to wide data set 

df.pivot(index='country', columns='year', values='lifeExp')
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
temp_df= df.pivot(index='country', columns='year', values='lifeExp')

# %%
#axis level, no figure level function 
plt.figure(figsize=(15,15))
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %% [markdown]
# - jitna blue hai utna utna kamm hai, jitna white ahi utna zyada hai

# %%
# customisations 
# just plotting graph for european countries 

euro = df[df.continent=='Europe']

# %%
euro
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  \
# 12           Albania    Europe  1952   55.230   1282697   1601.056136
# 13           Albania    Europe  1957   59.280   1476505   1942.284244
# 14           Albania    Europe  1962   64.820   1728137   2312.888958
# 15           Albania    Europe  1967   66.220   1984060   2760.196931
# 16           Albania    Europe  1972   67.690   2263554   3313.422188
# ...              ...       ...   ...      ...       ...           ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280
#
#      iso_alpha  iso_num
# 12         ALB        8
# 13         ALB        8
# 14         ALB        8
# 15         ALB        8
# ...

# %%
euro.pivot(index='country', columns='year', values='lifeExp')
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
#annot 

plt.figure(figsize=(12,8))
sns.heatmap(euro.pivot(index='country', columns='year', values='lifeExp'),annot=True)
plt.show()

# %%
#increase readablity

plt.figure(figsize=(12,8))
sns.heatmap(euro.pivot(index='country', columns='year', values='lifeExp'),annot=True,linewidths=0.5)
plt.show()

# %%
# change color scheme 
# YlGnBu , Blues , BuPu, Greens

plt.figure(figsize=(12,8))
sns.heatmap(euro.pivot(index='country', columns='year', values='lifeExp'),annot=True,linewidths=0.5,cmap='Blues')
plt.show()

# %% [markdown]
# # cluster map
#
# #### Plot a matrix dataset as a hierarchically-cluster heatmap
#
# #### This function requires scipy to be available

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(df.iloc[:,[0,1,2,3]]) #iloc(start row: end row,[index of labels, 0,1,2,3])

# %% [markdown]
# # categorical plot
#
# 1. BarPlot
# 2. countplot
# 3. Boxplot
# 4. Voilin

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.barplot(x=df.continent, y=df.lifeExp, ci=None)
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>
